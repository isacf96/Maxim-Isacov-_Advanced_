# %%
import pandas as pd
import numpy as np

# %%
bl=pd.read_csv(r'C:\Users\User\Downloads\2021 ML BL for Export (10).txt', sep='\t', dtype={'CS_UPC_NR_CD': 'str'})
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,2,4,8,10,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
bl
# Out:
#          CUST_ID_NR_CD  IND_ACCT_NR_CD PROMO_PLN_ID_NR_CD  PROMO_PLN_YR_CD  \
# 0               003107               0                FC1             2021
# 1               003111               0                FC1             2021
# 2               003113               0                FC1             2021
# 3               003114               0                FC1             2021
# 4               003134               0                FC1             2021
# ...                ...             ...                ...              ...
# 15935382          3374               0                NaN             2023
# 15935383          3374               0                NaN             2023
# 15935384          3374               0                NaN             2023
# 15935385          3374               0                NaN             2023
# 15935386          3374               0                NaN             2023
#
# ...

# %%
ph=pd.read_excel(r'C:\Users\User\Downloads\DHUB PH Extract (6).xlsx', usecols=['Code', 'Find CaseUPC', 'Category', 'Forecast Group'])
# Out:
# C:\Users\User\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
ph.head()
# Out:
#              Code Forecast Group             Category  Find CaseUPC
# 0  10079400277760           01B3  DEO-MALE TOILETRIES  007940027776
# 1  10079400048636           0410  DEO-MALE TOILETRIES  007940004863
# 2  10079400473537           03MS  DEO-MALE TOILETRIES  007940047353
# 3  10079400106381           0714  DEO-MALE TOILETRIES  007940010638
# 4  10079400312973           01P5  DEO-MALE TOILETRIES  007940031297

# %%
ph.rename(columns={'Find CaseUPC': 'CS_UPC_NR_CD'}, inplace=True)

# %%
bl = pd.merge(bl,ph,how='left')

# %%
bl
# Out:
#          CUST_ID_NR_CD  IND_ACCT_NR_CD PROMO_PLN_ID_NR_CD  PROMO_PLN_YR_CD  \
# 0               003107               0                FC1             2021
# 1               003111               0                FC1             2021
# 2               003113               0                FC1             2021
# 3               003114               0                FC1             2021
# 4               003134               0                FC1             2021
# ...                ...             ...                ...              ...
# 15935382          3374               0                NaN             2023
# 15935383          3374               0                NaN             2023
# 15935384          3374               0                NaN             2023
# 15935385          3374               0                NaN             2023
# 15935386          3374               0                NaN             2023
#
# ...

# %%
l = [44,45,46,47]

# %%
bl['WEEK_NR'] = bl['WEEK_NR'].astype(int)

# %%
bl[(bl['Forecast Group']=='0759')&(bl['WEEK_NR'].isin(l))&(bl['PROMO_PLN_YR_CD']==2021)&(bl['CUST_ID_NR_CD']==3338)]['SUPPLEMENTAL_VOLUME_NR'].sum()
# Out:
# 6455.315557

# %%
bl[(bl['Forecast Group']=='0759')&(bl['WEEK_NR'].isin(l))&(bl['PROMO_PLN_YR_CD']==2021)&(bl['CUST_ID_NR_CD']==3338)].groupby('CS_UPC_NR_CD').sum()
# Out:
#               IND_ACCT_NR_CD  PROMO_PLN_YR_CD  CS_UPC_VRSN_NR_CD  WEEK_NR  \
# CS_UPC_NR_CD
# 007940045947               0             8084                0.0      182
# 007940052375               0             8084                0.0      182
# 007940052376               0             8084                0.0      182
# 007940063763               0             8084                0.0      182
# 007940064676               0             8084                0.0      182
# 007940064677               0             8084                0.0      182
# 007940064678               0             8084                0.0      182
# 007940064679               0             8084                0.0      182
#
#               SUPPLEMENTAL_VOLUME_NR          Code
# CS_UPC_NR_CD
# 007940045947              473.836000  4.031760e+13
# 007940052375                0.000000  4.031760e+13
# 007940052376                0.000000  4.031760e+13
# 007940063763             1945.165475  4.031760e+13
# ...

# %%
bl[(bl['Forecast Group']=='0AUQ')&(bl['WEEK_NR'].isin(l))&(bl['PROMO_PLN_YR_CD']==2021)&(bl['CUST_ID_NR_CD']==3338)]
# Out:
# Empty DataFrame
# Columns: [CUST_ID_NR_CD, IND_ACCT_NR_CD, PROMO_PLN_ID_NR_CD, PROMO_PLN_YR_CD, BRND_NR_CD, CS_UPC_NR_CD, CS_UPC_VRSN_NR_CD, WEEK_NR, SOURCE_CD, SUPPLEMENTAL_VOLUME_NR, CAT_NR_CD, FMLY_NR_CD, Code, Category, Forecast Group]
# Index: []

# %%
ACTPM_export_211102

# %%
actpm=pd.read_csv(r'C:\Users\User\Downloads\ACTPM_export_211102.txt')

# %%
actpm
# Out:
#          SalesOrg         AcctID               AcctName           PrdID  Year  \
# 0               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251906  2021
# 1               1  000394-001094         GREAT AMERICAN  10079400251906  2021
# 2               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251807  2021
# 3               1  000394-001094         GREAT AMERICAN  10079400251807  2021
# 4               1  000394-001094         GREAT AMERICAN  10079400507300  2021
# ...           ...            ...                    ...             ...   ...
# 3798969         1  000627-000000  Albertsons BOISE - PC  10811346020747  2022
# 3798970         1  000627-000000  Albertsons BOISE - PC  20811346021000  2022
# 3798971         1  000627-000000  Albertsons BOISE - PC  10811346021348  2022
# 3798972         1  000627-000000  Albertsons BOISE - PC  20811346021383  2022
# 3798973         1  000174-000000               WAL-MART  20811346021000  2022
#
#          Week      Date  Volume
# ...

# %%
actpm.rename(columns={'PrdID': 'Code'}, inplace=True)

# %%
actpm
# Out:
#          SalesOrg         AcctID               AcctName            Code  Year  \
# 0               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251906  2021
# 1               1  000394-001094         GREAT AMERICAN  10079400251906  2021
# 2               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251807  2021
# 3               1  000394-001094         GREAT AMERICAN  10079400251807  2021
# 4               1  000394-001094         GREAT AMERICAN  10079400507300  2021
# ...           ...            ...                    ...             ...   ...
# 3798969         1  000627-000000  Albertsons BOISE - PC  10811346020747  2022
# 3798970         1  000627-000000  Albertsons BOISE - PC  20811346021000  2022
# 3798971         1  000627-000000  Albertsons BOISE - PC  10811346021348  2022
# 3798972         1  000627-000000  Albertsons BOISE - PC  20811346021383  2022
# 3798973         1  000174-000000               WAL-MART  20811346021000  2022
#
#          Week      Date  Volume
# ...

# %%
ph
# Out:
#                  Code Forecast Group             Category  CS_UPC_NR_CD
# 0      10079400277760           01B3  DEO-MALE TOILETRIES  007940027776
# 1      10079400048636           0410  DEO-MALE TOILETRIES  007940004863
# 2      10079400473537           03MS  DEO-MALE TOILETRIES  007940047353
# 3      10079400106381           0714  DEO-MALE TOILETRIES  007940010638
# 4      10079400312973           01P5  DEO-MALE TOILETRIES  007940031297
# ...               ...            ...                  ...           ...
# 40246  10055451002148           0CD5           ELIDA HAIR  005545100214
# 40247  10055451002124           0CD5           ELIDA HAIR  005545100212
# 40248  10055451002117           0CD5           ELIDA HAIR  005545100211
# 40249  10055451002131           0CD5           ELIDA HAIR  005545100213
# 40250  80055451526230           0CD8           ELIDA HAIR  005545152623
#
# [40251 rows x 4 columns]

# %%
actpm = pd.merge(actpm,ph,how='left')

# %%
actpm
# Out:
#          SalesOrg         AcctID               AcctName            Code  Year  \
# 0               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251906  2021
# 1               1  000394-001094         GREAT AMERICAN  10079400251906  2021
# 2               1  000621-001133   C&S WHSLE SACRAMENTO  10079400251807  2021
# 3               1  000394-001094         GREAT AMERICAN  10079400251807  2021
# 4               1  000394-001094         GREAT AMERICAN  10079400507300  2021
# ...           ...            ...                    ...             ...   ...
# 3798969         1  000627-000000  Albertsons BOISE - PC  10811346020747  2022
# 3798970         1  000627-000000  Albertsons BOISE - PC  20811346021000  2022
# 3798971         1  000627-000000  Albertsons BOISE - PC  10811346021348  2022
# 3798972         1  000627-000000  Albertsons BOISE - PC  20811346021383  2022
# 3798973         1  000174-000000               WAL-MART  20811346021000  2022
#
# ...

# %%
actpm[(actpm['Forecast Group']=='0AUQ')&(actpm['Week'].isin(l))&(actpm['Year']==2021)&(actpm['AcctID']=='003338-000000')]['Volume'].sum()
# Out:
# 0

# %% [markdown]
# Plans

# %%
plans=pd.read_csv(r'C:\Users\User\Downloads\DOMO_UPC_PLANS EXPORT_210923.csv')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
plans
# Out:
#            PAD  PAI      CASE_UPC     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE
# 0            4    0  001111100094  W202138     0.0        0.0    1632.04
# 1            4    0  001111100094  W202139     0.0        0.0    1632.04
# 2            4    0  001111100094  W202140     0.0        0.0    1632.04
# 3            4    0  001111100094  W202141     0.0        0.0    1632.04
# 4            4    0  001111100094  W202142     0.0        0.0    1632.04
# ...        ...  ...           ...      ...     ...        ...        ...
# 13794580  3466    0   73291345027  W202248     0.0        0.0      19.32
# 13794581  3466    0   73291345027  W202249     0.0        0.0      19.32
# 13794582  3466    0   73291345027  W202250     0.0        0.0      19.32
# 13794583  3466    0   73291345027  W202251     0.0        0.0      19.32
# 13794584  3466    0   73291345027  W202252     0.0        0.0      19.32
#
# [13794585 rows x 7 columns]

# %%
ph
# Out:
#                  Code Forecast Group             Category  CS_UPC_NR_CD
# 0      10079400277760           01B3  DEO-MALE TOILETRIES  007940027776
# 1      10079400048636           0410  DEO-MALE TOILETRIES  007940004863
# 2      10079400473537           03MS  DEO-MALE TOILETRIES  007940047353
# 3      10079400106381           0714  DEO-MALE TOILETRIES  007940010638
# 4      10079400312973           01P5  DEO-MALE TOILETRIES  007940031297
# ...               ...            ...                  ...           ...
# 40246  10055451002148           0CD5           ELIDA HAIR  005545100214
# 40247  10055451002124           0CD5           ELIDA HAIR  005545100212
# 40248  10055451002117           0CD5           ELIDA HAIR  005545100211
# 40249  10055451002131           0CD5           ELIDA HAIR  005545100213
# 40250  80055451526230           0CD8           ELIDA HAIR  005545152623
#
# [40251 rows x 4 columns]

# %%
plans.rename(columns={'CASE_UPC': 'CS_UPC_NR_CD'}, inplace=True)

# %%
plans['CS_UPC_NR_CD']=plans['CS_UPC_NR_CD'].astype(str).str.zfill(12)

# %%
plans = pd.merge(plans,ph,how='left')

# %%
plans
# Out:
#            PAD  PAI  CS_UPC_NR_CD     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE  \
# 0            4    0  001111100094  W202138     0.0        0.0    1632.04
# 1            4    0  001111100094  W202139     0.0        0.0    1632.04
# 2            4    0  001111100094  W202140     0.0        0.0    1632.04
# 3            4    0  001111100094  W202141     0.0        0.0    1632.04
# 4            4    0  001111100094  W202142     0.0        0.0    1632.04
# ...        ...  ...           ...      ...     ...        ...        ...
# 13794580  3466    0  073291345027  W202248     0.0        0.0      19.32
# 13794581  3466    0  073291345027  W202249     0.0        0.0      19.32
# 13794582  3466    0  073291345027  W202250     0.0        0.0      19.32
# 13794583  3466    0  073291345027  W202251     0.0        0.0      19.32
# 13794584  3466    0  073291345027  W202252     0.0        0.0      19.32
#
#                   Code Forecast Group                 Category
# ...

# %%
plans['Category'].unique()
# Out:
# array(['PERSONAL WASH', 'ELIDA PERSONAL WASH', 'HAIR CARE', 'SPREADS',
#        'KNORR', 'GHB NOVELTIES', 'MEALMAKERS', 'TEA', nan,
#        'SKIN CARE - BODY', 'TOTAL CONDIMENTS', 'SUPER PREMIUM ICE CREAM',
#        'SKIN CARE - FACE', 'GHB PACKAGED', 'DEO-MALE TOILETRIES',
#        'ELIDA Q-TIPS', 'Q-TIPS-MISC', 'HOME CARE', 'SUNDIAL',
#        'SVG OTHER PERSONAL CARE', 'ORAL CARE', 'ELIDA SKIN CARE FACE',
#        'DOLLAR SHAVE CLUB', 'POURABLES', 'ELIDA DEO-MALE TOILETRIES',
#        'PROFESSIONAL', 'MISC. OTHER FOODS', 'RPL SPREADS',
#        'B&J INGREDIENTS'], dtype=object)

# %%
l1 = ['W202140']

# %%
l2 = ['HAIR CARE', 'DEO-MALE TOILETRIES', 'SUNDIAL']

# %%
plans = plans[(plans['WEEK'].isin(l1))&(plans['PAD']==3338)&(plans['Category'].isin(l2))]

# %%
#plans[(plans['Forecast Group']=='0AUQ')&(plans['WEEK'].isin(l1))&(plans['PAD']==3338)]

# %%
plans
# Out:
#            PAD  PAI  CS_UPC_NR_CD     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE  \
# 11869287  3338    0  002240000028  W202140     0.0       0.00      28.32
# 11869354  3338    0  002240000032  W202140    23.0     651.36      28.32
# 11869421  3338    0  002240000043  W202140     0.0       0.00      16.72
# 11869488  3338    0  002240000044  W202140     0.0       0.00      16.72
# 11869555  3338    0  002240000046  W202140     0.0       0.00      16.72
# ...        ...  ...           ...      ...     ...        ...        ...
# 12068184  3338    0  176430220430  W202140    11.0    1586.64     144.24
# 12069591  3338    0  871160075340  W202140     0.0       0.00      49.08
# 12069658  3338    0  871160075384  W202140     0.0       0.00      49.08
# 12069725  3338    0  871170071680  W202140     0.0       0.00      49.08
# 12069792  3338    0  871256146682  W202140     0.0       0.00       0.00
#
#                   Code Forecast Group   Category
# ...

# %%
plans['WEEK'].unique()
# Out:
# array(['W202140'], dtype=object)

# %%
plans['PAD'].unique()
# Out:
# array([3338], dtype=int64)

# %%
plans['Category'].unique()
# Out:
# array(['HAIR CARE', 'DEO-MALE TOILETRIES', 'SUNDIAL'], dtype=object)

# %%
plans210923 = plans

# %%
plans210923
# Out:
#            PAD  PAI  CS_UPC_NR_CD     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE  \
# 11869287  3338    0  002240000028  W202140     0.0       0.00      28.32
# 11869354  3338    0  002240000032  W202140    23.0     651.36      28.32
# 11869421  3338    0  002240000043  W202140     0.0       0.00      16.72
# 11869488  3338    0  002240000044  W202140     0.0       0.00      16.72
# 11869555  3338    0  002240000046  W202140     0.0       0.00      16.72
# ...        ...  ...           ...      ...     ...        ...        ...
# 12068184  3338    0  176430220430  W202140    11.0    1586.64     144.24
# 12069591  3338    0  871160075340  W202140     0.0       0.00      49.08
# 12069658  3338    0  871160075384  W202140     0.0       0.00      49.08
# 12069725  3338    0  871170071680  W202140     0.0       0.00      49.08
# 12069792  3338    0  871256146682  W202140     0.0       0.00       0.00
#
#                   Code Forecast Group   Category
# ...

# %%
plans210923['CS_UPC_NR_CD'].nunique()
# Out:
# 1621

# %%
plans210726
# Out:
#            PAD  PAI  CS_UPC_NR_CD     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE  \
# 12857527  3338    0  002240000028  W202140     0.0       0.00      28.32
# 12857603  3338    0  002240000032  W202140     0.0       0.00      28.32
# 12857679  3338    0  002240000043  W202140     0.0       0.00      16.72
# 12857755  3338    0  002240000044  W202140     0.0       0.00      16.72
# 12857831  3338    0  002240000046  W202140     0.0       0.00      16.72
# ...        ...  ...           ...      ...     ...        ...        ...
# 13078147  3338    0  176430220430  W202140     2.0     288.48     144.24
# 13079743  3338    0  871160075340  W202140     0.0       0.00       0.00
# 13079819  3338    0  871160075384  W202140     0.0       0.00       0.00
# 13079895  3338    0  871170071680  W202140     0.0       0.00      49.08
# 13079971  3338    0  871256146682  W202140     0.0       0.00       0.00
#
#                   Code Forecast Group   Category
# ...

# %%
plans210726['CS_UPC_NR_CD'].nunique()
# Out:
# 1558

# %%
plans_f = pd.merge(plans210923, plans210726, how='left')

# %%
plans_f
# Out:
#        PAD  PAI  CS_UPC_NR_CD     WEEK  PHY_CS  PLAN_UNSV  NSV_PRICE  \
# 0     3338    0  002240000028  W202140     0.0       0.00      28.32
# 1     3338    0  002240000032  W202140    23.0     651.36      28.32
# 2     3338    0  002240000043  W202140     0.0       0.00      16.72
# 3     3338    0  002240000044  W202140     0.0       0.00      16.72
# 4     3338    0  002240000046  W202140     0.0       0.00      16.72
# ...    ...  ...           ...      ...     ...        ...        ...
# 1616  3338    0  176430220430  W202140    11.0    1586.64     144.24
# 1617  3338    0  871160075340  W202140     0.0       0.00      49.08
# 1618  3338    0  871160075384  W202140     0.0       0.00      49.08
# 1619  3338    0  871170071680  W202140     0.0       0.00      49.08
# 1620  3338    0  871256146682  W202140     0.0       0.00       0.00
#
#               Code Forecast Group   Category
# 0     1.002240e+13           06KQ  HAIR CARE
# 1     1.002240e+13           06KQ  HAIR CARE
# ...

# %%
plans210923.

# %%
plans210726

# %%
plans210923.to_csv('plans210923.csv', index=False)

# %%
plans210726.to_csv('plans210726.csv', index=False)

# %%
total=pd.read_csv(r'C:\Users\User\Downloads\total_forecast_ML141021.csv', delimiter='|')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
total
# Out:
#          CUST_ID_NR_CD  IND_ACCT_NR_CD  PROMO_PLN_ID_NR_CD  PROMO_PLN_YR_CD  \
# 0                    4               0                 NaN             2021
# 1                    4               0                 NaN             2021
# 2                    4               0                 NaN             2021
# 3                    4               0                 NaN             2021
# 4                    4               0                 NaN             2021
# ...                ...             ...                 ...              ...
# 4444404             52               0                 NaN             2022
# 4444405             52               0                 NaN             2022
# 4444406             52               0                 NaN             2022
# 4444407             52               0                 NaN             2022
# 4444408             52               0                 NaN             2023
#
# ...
